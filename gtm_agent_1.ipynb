# %%
# ORIGINAL

# Step 1: Define tools and model

from langchain.tools import tool
from langchain.chat_models import init_chat_model
from dotenv import dotenv_values

config = dotenv_values(".env")

model = init_chat_model(
    "gpt-4.1-mini",
    model_provider="openai",
    api_key=config["OPEN_AI_KEY"]
)


# Define tools
@tool
def multiply(a: int, b: int) -> int:
    """Multiply `a` and `b`.

    Args:
        a: First int
        b: Second int
    """
    return a * b


@tool
def add(a: int, b: int) -> int:
    """Adds `a` and `b`.

    Args:
        a: First int
        b: Second int
    """
    return a + b


@tool
def divide(a: int, b: int) -> float:
    """Divide `a` and `b`.

    Args:
        a: First int
        b: Second int
    """
    return a / b


# Augment the LLM with tools
tools = [add, multiply, divide]
tools_by_name = {tool.name: tool for tool in tools}
model_with_tools = model.bind_tools(tools)

# Step 2: Define state

from langchain.messages import AnyMessage
from typing_extensions import TypedDict, Annotated
import operator


class MessagesState(TypedDict):
    messages: Annotated[list[AnyMessage], operator.add]
    llm_calls: int

# Step 3: Define model node
from langchain.messages import SystemMessage


def llm_call(state: dict):
    """LLM decides whether to call a tool or not"""

    return {
        "messages": [
            model_with_tools.invoke(
                [
                    SystemMessage(
                        content="You are a helpful assistant tasked with performing arithmetic on a set of inputs."
                    )
                ]
                + state["messages"]
            )
        ],
        "llm_calls": state.get('llm_calls', 0) + 1
    }


# Step 4: Define tool node

from langchain.messages import ToolMessage


def tool_node(state: dict):
    """Performs the tool call"""

    result = []
    for tool_call in state["messages"][-1].tool_calls:
        tool = tools_by_name[tool_call["name"]]
        observation = tool.invoke(tool_call["args"])
        result.append(ToolMessage(content=observation, tool_call_id=tool_call["id"]))
    return {"messages": result}

# Step 5: Define logic to determine whether to end

from typing import Literal
from langgraph.graph import StateGraph, START, END


# Conditional edge function to route to the tool node or end based upon whether the LLM made a tool call
def should_continue(state: MessagesState) -> Literal["tool_node", END]:
    """Decide if we should continue the loop or stop based upon whether the LLM made a tool call"""

    messages = state["messages"]
    last_message = messages[-1]

    # If the LLM makes a tool call, then perform an action
    if last_message.tool_calls:
        return "tool_node"

    # Otherwise, we stop (reply to the user)
    return END

# Step 6: Build agent

# Build workflow
agent_builder = StateGraph(MessagesState)

# Add nodes
agent_builder.add_node("llm_call", llm_call)
agent_builder.add_node("tool_node", tool_node)

# Add edges to connect nodes
agent_builder.add_edge(START, "llm_call")
agent_builder.add_conditional_edges(
    "llm_call",
    should_continue,
    ["tool_node", END]
)
agent_builder.add_edge("tool_node", "llm_call")

# Compile the agent
agent = agent_builder.compile()


from IPython.display import Image, display
# Show the agent
display(Image(agent.get_graph(xray=True).draw_mermaid_png()))

# Invoke
from langchain.messages import HumanMessage
messages = [HumanMessage(content="Add 3 and 4.")]
messages = agent.invoke({"messages": messages})
for m in messages["messages"]:
    m.pretty_print()
# Out:
# ================================ Human Message =================================
#
# Add 3 and 4.
# ================================== Ai Message ==================================
# Tool Calls:
#   add (call_ZnP7Nc5Z5f8EUU110ZqP3SkP)
#  Call ID: call_ZnP7Nc5Z5f8EUU110ZqP3SkP
#   Args:
#     a: 3
#     b: 4
# ================================= Tool Message =================================
#
# 7
# ================================== Ai Message ==================================
#
# The sum of 3 and 4 is 7.

# %%
# UPDATE

# Step 1: Define tools and model

from langchain.tools import tool
from langchain.chat_models import init_chat_model
from dotenv import dotenv_values
from langchain_tavily import TavilySearch

config = dotenv_values(".env")

model = init_chat_model(
    "gpt-4.1-mini",
    model_provider="openai",
    api_key=config["OPEN_AI_KEY"]
)


# Define tools
tavily_tool = TavilySearch(
    max_results=5,
    topic="general",
    tavily_api_key=config["TAVILY_API_KEY"]
)


# Augment the LLM with tools
tools = [tavily_tool]
tools_by_name = {tool.name: tool for tool in tools}
model_with_tools = model.bind_tools(tools)

# Step 2: Define state

from langchain.messages import AnyMessage
from typing_extensions import TypedDict, Annotated
import operator


class MessagesState(TypedDict):
    messages: Annotated[list[AnyMessage], operator.add]
    llm_calls: int

# Step 3: Define model node
from langchain.messages import SystemMessage


def llm_call(state: dict):
    """LLM decides whether to call a tool or not"""

    return {
        "messages": [
            model_with_tools.invoke(
                [
                    SystemMessage(
                        content="You are a helpful Go-To-Market assistant tasked with performing research on finding good leads for my business. Use the TavilySearch tool to find leads online."
                    )
                ]
                + state["messages"]
            )
        ],
        "llm_calls": state.get('llm_calls', 0) + 1
    }


# Step 4: Define tool node

from langchain.messages import ToolMessage


def tool_node(state: dict):
    """Performs the tool call"""

    result = []
    for tool_call in state["messages"][-1].tool_calls:
        tool = tools_by_name[tool_call["name"]]
        observation = tool.invoke(tool_call)
        if isinstance(observation, ToolMessage):
            result.append(observation)
        else:
            result.append(ToolMessage(content=str(observation), tool_call_id=tool_call["id"]))
    return {"messages": result}

# Step 5: Define logic to determine whether to end

from typing import Literal
from langgraph.graph import StateGraph, START, END


# Conditional edge function to route to the tool node or end based upon whether the LLM made a tool call
def should_continue(state: MessagesState) -> Literal["tool_node", END]:
    """Decide if we should continue the loop or stop based upon whether the LLM made a tool call"""

    messages = state["messages"]
    last_message = messages[-1]

    # If the LLM makes a tool call, then perform an action
    if last_message.tool_calls:
        return "tool_node"

    # Otherwise, we stop (reply to the user)
    return END

# Step 6: Build agent

# Build workflow
agent_builder = StateGraph(MessagesState)

# Add nodes
agent_builder.add_node("llm_call", llm_call)
agent_builder.add_node("tool_node", tool_node)

# Add edges to connect nodes
agent_builder.add_edge(START, "llm_call")
agent_builder.add_conditional_edges(
    "llm_call",
    should_continue,
    ["tool_node", END]
)
agent_builder.add_edge("tool_node", "llm_call")

# Compile the agent
agent = agent_builder.compile()


from IPython.display import Image, display
# Show the agent
display(Image(agent.get_graph(xray=True).draw_mermaid_png()))

# Invoke
from langchain.messages import HumanMessage
messages = [HumanMessage(content="Find some good fitness influencer leads on Instagram and ensure you also provide their Instagram handle.")]
messages = agent.invoke({"messages": messages})
for m in messages["messages"]:
    m.pretty_print()
# Out:
# ================================ Human Message =================================
#
# Find some good fitness influencer leads on Instagram and ensure you also provide their Instagram handle.
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search (call_Zftcm8erMzO41ixsIm0NhYhO)
#  Call ID: call_Zftcm8erMzO41ixsIm0NhYhO
#   Args:
#     query: top fitness influencers on Instagram
#     search_depth: advanced
#     include_images: False
#     time_range: year
# ================================= Tool Message =================================
# Name: tavily_search
#
# {"query": "top fitness influencers on Instagram", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.fitbudd.com/post/top-fitness-influencers-2026", "title": "Top Fitness Influencers to Follow for Your Best Health Journey", "content": "The true masterclass in scaling your brand lies in observing the top fitness influencers on Instagram and dissecting their approach. These aren’t just people taking pictures; they are highly specialized content machines. Each social media influencer leverages their platforms to maximize reach and engagement, consistently sharing high-quality posts that inspire and educate their followers. We’ve broken down 8 of the most dominant global figures, grouped by the specialization that drives their massive, monetized audiences, and the diverse fitness content they produce, from workout tutorials and wellness advice to motivational and lifestyle posts. Many of these influencers have received significant media attention for their achievements and influence, capturing global attention. [...] ## Why These Fitness Influencers Dominate Instagram\n\nThe difference between a successful coach and a dominant fitness influencer isn’t just raw follower count. It’s in the deliberate, systematic methods they use to attract and hold attention while building a robust, diversified business model. Each influencer often develops a signature fitness method that sets them apart, whether it's a unique training philosophy, structured workout system, or holistic approach. They have mastered the art of providing immense value, often for free, and have built a reputation as a fitness expert in their chosen niche. [...] From a business perspective, Drea exemplifies how fitness influencers scale beyond social platforms by owning the customer relationship through a subscription-based app, transforming attention into predictable recurring revenue.\n\nInstagram: Drea Thomas (@dreathomas) • Instagram photos and videos\n\n## How Influencers Convert Followers to Clients?\n\nAnalyzing the strategies of these top fitness influencers on Instagram reveals one core truth: they don’t coach in their DMs. They use Instagram to build trust and attention, but they use technology to deliver and monetize. The scale they achieve is impossible using manual one-on-one booking or generic link-in-bio tools.", "score": 0.9999895, "raw_content": null}, {"url": "https://lefty.io/blog/top-fitness-influencers", "title": "Instagram's Top Fitness Influencers - Lefty", "content": "## Fitness Influencers' Impact in 2025\n\nWhether you're a brand seeking impactful partnerships or a fitness enthusiast looking for daily inspiration, these top fitness influencers are leading the charge in 2025. From gym influencers like Chris Bumstead redefining performance and authenticity to female fitness influencers like Michelle Lewin and Kayla Itsines empowering global communities, each profile highlights the diverse and dynamic world of fitness influencers on Instagram. Their influence goes beyond workouts—they shape trends, promote healthier lifestyles, and open up exciting opportunities for brands in the wellness space. As the online fitness community continues to grow, these fitness influencers will remain essential voices in shaping what’s next. [...] # Instagram’s Top Fitness Influencers\n\nDiscover the 20 Top Fitness Influencers on Instagram in 2025! From gym influencers to female fitness icons, these top fitness influencers inspire healthier lifestyles and create big opportunities for brands and fitness enthusiasts alike.\n\nExplore the 20 leading fitness influencers to follow on Instagram in 2025! These trailblazers not only inspire healthier, more active lifestyles but also offer exceptional opportunities for brands. A true destination for fitness enthusiasts around the globe!", "score": 0.99997807, "raw_content": null}, {"url": "https://wod.guru/blog/fitness-influencers/", "title": "50+ Top Famous Fitness Influencers (To Fol ...
# ================================== Ai Message ==================================
#
# Here are some good fitness influencer leads on Instagram with their handles:
#
# 1. Drea Thomas - @dreathomas
# 2. Massy Arias - @massy.arias (3.1M followers)
# 3. Simeon Panda - @simeonpanda (Over 8M followers)
# 4. Ruba Ali - @realrubaali (1.6M followers)
# 5. Annabel Lucinda - @annabel.lucinda (3.2M followers)
# 6. Ulisses Junior - @ulissesworld (8M followers)
# 7. Lazar Angelov - @lazar_angelov_official (6.2M followers)
# 8. Kai Greene - @kaigreene (7.3M followers)
# 9. Lisa Migliorini - @lisamigliorini (2.4M followers)
# 10. Gustavo Aguirre - @gustavoaguirre199 (153K followers)
# 11. Victoria Terletska - @victoria.terletska (63.7K followers)
# 12. Simple Nolan - @simplenolan1 (63.5K followers)
# 13. Sasha - @sashameetsfitness (10.6K followers)
#
# These influencers cover a wide range of fitness niches including bodybuilding, calisthenics, running, home workouts, and holistic wellness. They have large followings and are influential in the fitness community on Instagram.
